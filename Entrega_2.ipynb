# %% [markdown]
# # Arquitectura del computador - Politécnico Grancolombiano
#
#
# ## Integrantes
#
# - Raúl Enrique Moncada Cod. 100060698
# - Luis Eduardo Antonio Peña Cod. 100223553
# - Didier jose Hurtado Bohorquez Cod. 2011025894
#
#
# **Índice**
#
# 1. [Problema](#id1)
# 2. [Algoritmo](#id2)
# 3. [Instrucciones](#id3)
# 4. [Resumen del código](#id4)
# 5. [Tipos de datos](#id5)
# 6. [Registros](#id6)
# 7. [Direccionamiento](#id7)
# 8. [Algoritmo a bajo nivel](#id8)
# 9. [Binario en Hexa](#id9)
# 10. [ALU en Logisim](#id10)
#
#
# ## Entrega 1
#
#
# ### Problema<a name="id1"></a>
#
# Se debe construir en lenguaje de alto nivel un algoritmo que permita verificar si un número es primo o no. La teoría nos indica que un número es primo, cuando es divisible por `1` y por sí mismo.
# Por lo tanto, para resolver este problema, se debe dividir el número a comprobar entre los números menores a este y comprobar su módulo o residuo, si este llega a ser `0` significa que tiene más de un divisor y por lo tanto no es primo.
# Otra forma de determinarlo, es comprobar que el módulo o residuo sea diferente de `0`, esto significa que no tiene divisores en sus números inferiores y por lo tanto, es primo.
#
# ### Algoritmo<a name="id2"></a>

# %%
#/usr/bin/python3

def esPrimo(num):
    if num < 1:
        return False
    elif num == 2:
        return True
    else:
        for i in range(2, num):
            if num % i == 0:
                return False
        return True            

def app():
    num = int(input('Escriba un número: '))
    result = esPrimo(num)

    if result is True:
        print('El número es primo!!')
    else:
        print('El número no es primo!!')

if __name__ == '__main__':
    app()
# Out:
# Escriba un número: 1
# El número es primo!!

# %% [markdown]
# ### Instrucciones<a name="id3"></a>
#
# **Tipos de instrucciones requeridas para la solución del problema de acuerdo con el algoritmo diseñado:**
#
# Una instrucción es un conjunto de datos insertados en una secuencia estructurada que ordena al intérprete realizar una operación determinada.
#
# De acuerdo con el algoritmo diseñado, las instrucciones requeridas son:
#
#
# **def esPrimo(num):**
#
# **if num < 1:**
#
# **return False**
#
# **elif num == 2:**
#
# **return True**
#
# **else:**
#
# **for i in range(2, num):**
#
# **if num % i == 0:**
#
# **return False**
#
# **return True**
#
# **def app():**
#
# **num = int(input('Escriba un número: '))**
#
# **result = esPrimo(num)**
#
# **if result is True:**
#
# **print('El número es primo!!')**
#
# **else:**
#
# **print('El número no es primo!!')**
#
# **if __name__ == '__main__':**
# **app()**

# %% [markdown]
# ### Resumen del código<a name="id4"></a>
#
# Para dar solución al problema planteado, es necesario saber que son los números primos.
#
# **Los numeros primos son aquellos números naturales mayores que 1 que solo son divisibles por si mismo y por 1.**
#
# Teniendo clara la definición de numeros primos, desarrollamos el algoritmo en Python de la siguente manera.
#
# - Se pide al usuario que escriba un número.
#
# - Se define la función **esPrimo** la cual toma como parametro el número ingresado por el usuario.
#
# - Se comprueba que el numero ingresado sea natural mayor que 1.
#
# - Se usa un bucle **For** para realizar las iteración, recorriendo los elementos desde 2 hasta el número ingresado por el usuario.
#
# - Se usa el operador módulo **(%)** en cada una de las iteraciones para optener el residuo de cada división.
#
# - Si en alguna de las iteraciones el módulo es "cero", el numero **NO** es primo y se debe mostar el memsaje: **"El número no es primo"**
#
# - Si por el contrario, en ninguna de las iteraciones el módulo es "cero", entonces el número es primo y se debe mostrar el mensaje **"El número es primo"**

# %% [markdown]
# ## Entrega 2
#
#
# ### Tipos de datos<a name="id5"></a>
#
# Estos son los tipos de datos que se identificaron dentro del algoritmo, para evitar un uso excesivo de memoria, se descartarán los tipos de datos que abarcan números negativos, por tal motivo, se usarán números de 1 a 255.
#
# | **Tipo de dato** | **Alto nivel** | **Bajo nivel** | **Valor**   |
# |------------------|----------------|----------------|-------------|
# |      Natural     |      Byte      |     8 bits     | 1 hasta 255 |
# |     Booleano     |      Bool      |      1 bit     |    0 o 1    |
#
#
# ### Registros<a name="id6"></a>
#
#
# |       **Nombre**       | **Mnemónico** |                   **Descripción**                   |   **Ejemplo**   |
# |:----------------------:|:-------------:|:---------------------------------------------------:|:---------------:|
# |     Load Immediate     |       li      |             Asignar un valor al registro            |      li v0      |
# |        Reminder        |      rem      |          Obtiene el residuo de una división         |    rem t2, t1   |
# |     Branch on equal    |      beq      | Condicional que evalúa si un valor es igual al otro |  beq s1,s2,for  |
# | Branch if greater than |      blt      |  Condicional que evalúa si un valor es menor a otro |    blt t0, t1   |
# |        Addition        |      add      |            Instrucción aritmética de suma           |    add t1, t2   |
# |         Switch         |       sw      |       Instrucción para guardar un valor en RAM      |    sw t2, t1    |
# |          Jump          |      jump     |            Saltar a otra línea de código            |       jump      |
#
#
# **Nota:** a las variables t0, t1, t2 se les debe anteponer un signo &#36; antes de su uso, por limitaciones de markdown la tabla se desordenaba al hacer esto
#
# ### Direccionamiento<a name="id7"></a>
#
# Los direccionamientos posibles que encontraremos son:
#
# **Relativo a PC:** Donde estará el contador, que tendrá como límite, el número a evaluar.
#
# **Indirecto a registro:** Todos las operaciones de comparación y ciclos if.
#
# **Inmediato:** Las operaciones en las que se evalúa si el residuo de una operación es 0 zero.
#
#
# ### Algoritmo a bajo nivel<a name="id8"></a>

# %%
.data
    insnum: .asciiz "Escriba un número: "
    
.main:  li $v0, 4 
        li $a0, insnum
        li $s0, 1 
        syscall
        add $t0, 0
        blt 1, $a0
        li $s0, 0
        jump .return
        blt 2, $a0
        li $s0, 1
        jump .return
        beq $s0,$a0,for
            rem $a1,$a0,s0
            beq $a1, $zero
            li $s0, 1
            jump return
        jump .return
.return:
        li $s0

# %% [markdown]
# ### Binario en Hexa<a name="id9"></a>
#
# | **Instrucción** | **Codop** | **Instrucción** | **Binario** | **Hex** |
# |-----------------|-----------|-----------------|-------------|---------|
# | Cargar          | 00        | 00000000        | 0000000000  | 0000    |
# | Comparar        | 01        | 00000000        | 0100000000  | 0100    |
# | Sumar           | 10        | 00000000        | 1000000000  | 0200    |
# | Residuo         | 11        | 00000000        | 1100000000  | 0300    |
# | Booleano        | 100       | 00000001        | 10000000001 | 0401    |
#
#
# ### ALU de logisim<a name="id10"></a>
#
# ![1.png](attachment:1.png)
#
#
# ## Entrega 3
#
# En el archivo circ se encuentra el ensamble completo de la microarquitectura. A continuación se observan las pruebas de de concepto, se puede observar cómo, al dar un número en binario y realiza el respectivo cálculo, iluminándose si es un número primo o no.
#
# ### Ejemplo con un número primo
#
# ![2.png](attachment:2.png)
#
#
# ### Ejemplo con un número que no es primo
#
# ![3.png](attachment:3.png)
#
#
# ### Conclusiones
#
# - La desarrollo de este tipo de arquitecturas es útil para diseñar circuitos a la medida, que realicen una tarea específica  sin recursos sobredimensionados.
# - Comprender la forma en la que funcionan los lenguajes a bajo nivel permite entender la forma en la que operan redes industriales SCADA.
# - Es posible llevar desarrollos en lenguaje de alto nivel para que funcionen como circuitos electrónicos.
# - La inclusión de arquitecturas desarrolladas a la medida permite ponderar correctamente los recursos que se asignarán a un proyecto.
